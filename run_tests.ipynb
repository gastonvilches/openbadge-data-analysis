# %%
from badge_data_analysis import preprocessing
from badge_data_analysis import tests
import os
# %matplotlib inline

# %% [markdown]
# First, the number of samples in each data packet is analyzed

# %%
filename = 'data/audio_data_test_1.txt'

tests.num_samples_analysis(filename)
# Out:
# All packets have 114 samples

# %% [markdown]
# Then, analyzing how constant is the sampling rate

# %%
data = preprocessing.read_file(filename)
data = preprocessing.fix_time_jumps(data)
fig, axes = tests.sampling_rate_uniformity(data)
